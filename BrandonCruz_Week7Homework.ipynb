# %% [markdown]
# # **Section 7.1**
# ## Question 1
# *Q: Using EVregistry, Write a query to select the ModelYear, Make, and Model off all of the vehicles in the registry.*
# ```SQL
# SELECT ModelYear, Make, Model
# FROM EVRegistry
# ```
# ## Question 2
# *Q: Using the EVRegistry table, Write a query that lists all of the unique types of EV's. your reult set should have one column, ElectricVehicleType.*
# ```SQL
# SELECT DISTINCT ElectricVehicleType
# FROM EVRegistry
# ```
# ## Question 3
# *Q: Using the EVRegistry, Write a query that shows all of the information on Battery Electric Vehicles (BEV) that are in the registry.*
# ```SQL
# SELECT *
# FROM EVRegistry
# WHERE ElectricVehicleType = 'Battery Electric Vehicle (BEV)'
# ```
# ## Question 4
# *Q: Using the EVRegistry, wirte a query that returns the Make and Model of all of the EV's that have a BaseMSRP between 20000 and 35000?*
# ```SQL
# SELECT Make, Model
# FROM EVRegistry
# WHERE BaseMSRP BETWEEN 20000 AND 35000;
# ```

# %% [markdown]
# # **Section 7.2**
# ## Question 1
# *Q: Using EVRegistry, write a query to find a record where the City attribute is NULL. Return all of the available columns.*
# ```SQL
# SELECT *
# FROM EVRegistry
# WHERE City IS NULL;
# ```
# ## Question 2
# *Q: Write a query to find the make, model, and ElectricVehicleType where the VIN number has that ends in '3E1EA1J'.*
# ```SQL
# SELECT Make, Model, ElectricVehicleType, VIN
# FROM EVRegistry
# WHERE vin like '%3E1EA1J'
# ```
# ## Question 3
# *Q: Select the ModelYear, make, model, ElectricVehicleType, and range of the Tesla vehicles or cheverolet vehicles in the registry. Order the result set by Make and Model year in from newest to oldest.*
# ```SQL
# SELECT ModelYear, Make, Model, ElectricVehicleType
# FROM EVRegistry
# WHERE Make = 'TESLA' or Make = 'CHEVEROLET'
# ORDER by make, ModelYear DESC
# ```
# ## Question 4
# *Q: Using EVCharging, Write a query to find out how many many times those stations were used. Order them by the most used to the least used and limit the output to 5 records.*
# ```SQL
# SELECT stationId, count (*) numberOfUses
# FROM EVCharging
# GROUP by stationId
# ORDER by numberOfUses DESC
# LIMIT 5
# ```
# ## Question 5
# *Q: Using EVCharging, For the folks who charged longer than 0.5 hours, show the min and max of the charging time for each user. Your output columns should be userid, minTime, and maxTime. Order this result set by the last two columns respectively.*
# ```SQL
# SELECT userId, min(chargeTimeHrs) as minTime, max(chargeTimeHrs) as maxTime
# FROM EVCharging
# WHERE chargeTimeHrs > 0.5
# GROUP by userId
# ORDER by min(chargeTimeHrs), max(chargeTimeHrs)
# ```

# %% [markdown]
# # **Section 7.3**
# ## Question 1
# *Q: Using EVCharging, Which day of the week has the highest average charging time? Round the answer to 2 decimal points.*
# ```SQL
# SELECT round(SUM(chargeTimeHrs),2) as totalOfHoursPerDay, weekday
# FROM EVCharging
# GROUP by weekday
# ORDER by totalOfHoursPerDay DESC
# LIMIT 1
# ```
# ## Question 2
# *Q: Using, EV charging, Find the total power consumed from charging EV's by each User. Return the userId and name the calculated column, totalPower. Round the answer to 2 deciaml points and list the out put in highest to lowest order. Limit the order to the top 15 users.*
# ```SQL
# SELECT userId, round(SUM(kwhTotal),2) as totalPower
# FROM EVCharging
# GROUP by userId
# order by totalPower desc
# LIMIT 15
# ```
# ## Question 3
# *Q: Using dimfacility and factCharge, write a query to find out which type of facility (GROUP BY) has the most amount of charging stations. Return type Facility and name the calculated column numStation. Order the result set from highest to lowest number of charging stations.*
# ```SQL
# SELECT b.typeFacility, COUNT(DISTINCT a.stationId) AS numStation
# FROM factCharge a
# INNER JOIN dimFacility b
# On a.facilityID = b.FacilityKey
# GROUP by b.typeFacility
# ORDER by numStation DESC;
# ```
# ## Question 4
# ##### *Q: In your own words, briefly explain Primary keys and Foreign Keys.*   <br> Primary keys are non null values that uniquely identify each record from a table. No other value can have that same ID. There is only one primary key per table and usually look something like "nameID." Additionally, foregin keys are essentially primary keys but just from a different table. Foreign keys uses the values used in another table, to create a link between two or more tables.
# ## Question 5
# *Q: Using EV Charging, For the folks who charged longer than one hour, show the min and max of the charging time for each user. Your output columns should be userid, minTime, and maxTime. Order this result set by the last two columns respectively. HINT: USE HAVING*
# ```SQL
# SELECT userId, min(chargeTimeHrs) as minTime, max(chargeTimeHrs) as maxTime
# FROM EVCharging
# GROUP by userId
# HAVING min(chargeTimeHrs) > 1
# ORDER by min(chargeTimeHrs), max(chargeTimeHrs)
# ```
